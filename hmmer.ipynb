#  16950K .......... .......... .......... .......... .......... 95%  106M 0s
#  17000K .......... .......... .......... .......... .......... 95%  418M 0s
#  17050K .......... .......... .......... .......... .......... 96%  420M 0s
#  17100K .......... .......... .......... .......... .......... 96%  408M 0s
#  17150K .......... .......... .......... .......... .......... 96% 12.5M 0s
#  17200K .......... .......... .......... .......... .......... 96% 21.8M 0s
#  17250K .......... .......... .......... .......... .......... 97% 18.6M 0s
#  17300K .......... .......... .......... .......... .......... 97%  249M 0s
#  17350K .......... .......... .......... .......... .......... 97%  372M 0s
#  17400K .......... .......... .......... .......... .......... 98%  394M 0s
#  17450K .......... .......... .......... .......... .......... 98%  418M 0s
#  17500K .......... .......... .......... .......... .......... 98%  399M 0s
#  17550K .......... .......... .......... .......... .......... 98% 24.0M 0s
#  17600K .......... .......... .......... .......... .......... 99% 31.3M 0s
#  17650K .......... .......... .......... .......... .......... 99% 54.1M 0s
#  17700K .......... .......... .......... .......... .......... 99% 14.5M 0s
#  17750K .......... .......... .......... ......               100% 67.2M=3.3s
#
# 2025-06-18 00:04:37 (5.24 MB/s) - ‘hmmer-3.3.2.tar.gz’ saved [18213049/18213049]

# %%
# %%bash
# cd hmmer-3.3.2
# ./configure
# make
# make install
# Out:
# configure: Configuring HMMER3 for your system.
# checking build system type... x86_64-pc-linux-gnu
# checking host system type... x86_64-pc-linux-gnu
# checking whether to compile using MPI... no
# checking for gcc... gcc
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to accept ISO C89... none needed
# checking for gcc option to accept ISO C99... none needed
# checking for gcc option to accept ISO Standard C... (cached) none needed
# checking how to run the C preprocessor... gcc -E
# checking for a BSD-compatible install... /usr/bin/install -c
# checking for strip... strip
# checking for ranlib... ranlib
# checking for ar... /usr/bin/ar
# checking whether ln -s works... yes
# checking for a sed that does not truncate output... /usr/bin/sed
# checking for grep that handles long lines and -e... /usr/bin/grep
# checking for egrep... /usr/bin/grep -E
# checking whether gcc is Clang... no
# checking whether pthreads work with -pthread... yes
# checking for joinable pthread attribute... PTHREAD_CREATE_JOINABLE
# checking whether more special flags are required for pthreads... no
# checking for PTHREAD_PRIO_INHERIT... yes
# checking whether gcc can compile our Altivec/VMX code... no
# checking whether gcc can compile our SSE code... yes
# configure: Activating Intel/AMD SSE vector DP implementation
# checking whether _MM_SET_FLUSH_ZERO_MODE is supported... yes
# checking compiler support --start-group... yes
# checking for gzip... /usr/bin/gzip
# checking for python3... yes
# checking for library containing clock_gettime... none required
# checking for ANSI C header files... yes
# checking for sys/types.h... yes
# checking for sys/stat.h... yes
# checking for stdlib.h... yes
# checking for string.h... yes
# checking for memory.h... yes
# checking for strings.h... yes
# checking for inttypes.h... yes
# checking for stdint.h... yes
# checking for unistd.h... yes
# checking endian.h usability... yes
# checking endian.h presence... yes
# checking for endian.h... yes
# checking for inttypes.h... (cached) yes
# checking for stdint.h... (cached) yes
# checking for unistd.h... (cached) yes
# checking for sys/types.h... (cached) yes
# checking netinet/in.h usability... yes
# checking netinet/in.h presence... yes
# checking for netinet/in.h... yes
# checking sys/param.h usability... yes
# checking sys/param.h presence... yes
# checking for sys/param.h... yes
# checking for sys/sysctl.h... no
# checking for uint8_t... yes
# checking for uint16_t... yes
# checking for uint32_t... yes
# checking for uint64_t... yes
# checking for off_t... yes
# checking whether byte ordering is bigendian... no
# checking for __attribute__((noreturn))... yes
# checking for __attribute__((format))... yes
# checking for mkstemp... yes
# checking for popen... yes
# checking for putenv... yes
# checking for strcasecmp... yes
# checking for strsep... yes
# checking for times... yes
# checking for getpid... yes
# checking for sysctl... no
# checking for sysconf... yes
# checking for getcwd... yes
# checking for chmod... yes
# checking for stat... yes
# checking for fstat... yes
# checking for erfc... no
# checking for library containing ntohs... none required
# checking for library containing ntohl... none required
# checking for library containing htons... none required
# checking for library containing htonl... none required
# checking for library containing socket... none required
# checking for library containing inet_pton... none required
# checking for _LARGEFILE_SOURCE value needed for large files... no
# checking for special C compiler options needed for large files... no
# checking for _FILE_OFFSET_BITS value needed for large files... no
# configure: creating ./config.status
# config.status: creating Makefile
# config.status: creating src/Makefile
# config.status: creating testsuite/Makefile
# config.status: creating profmark/Makefile
# config.status: creating src/impl_sse/Makefile
# config.status: creating documentation/Makefile
# config.status: creating documentation/man/Makefile
# config.status: creating documentation/userguide/Makefile
# config.status: creating documentation/userguide/inclusions/Makefile
# config.status: creating libdivsufsort/Makefile
# config.status: creating easel/Makefile
# config.status: creating easel/miniapps/Makefile
# config.status: creating easel/testsuite/Makefile
# config.status: creating easel/documentation/Makefile
# config.status: creating documentation/userguide/titlepage.tex
# config.status: creating documentation/userguide/titlepage_daemon.tex
# config.status: creating documentation/userguide/copyright.tex
# config.status: creating documentation/man/alimask.man
# config.status: creating documentation/man/hmmalign.man
# config.status: creating documentation/man/hmmbuild.man
# config.status: creating documentation/man/hmmc2.man
# config.status: creating documentation/man/hmmconvert.man
# config.status: creating documentation/man/hmmemit.man
# config.status: creating documentation/man/hmmer.man
# config.status: creating documentation/man/hmmfetch.man
# config.status: creating documentation/man/hmmlogo.man
# config.status: creating documentation/man/hmmpgmd.man
# config.status: creating documentation/man/hmmpgmd_shard.man
# config.status: creating documentation/man/hmmpress.man
# config.status: creating documentation/man/hmmscan.man
# config.status: creating documentation/man/hmmsearch.man
# config.status: creating documentation/man/hmmsim.man
# config.status: creating documentation/man/hmmstat.man
# config.status: creating documentation/man/jackhmmer.man
# config.status: creating documentation/man/makehmmerdb.man
# config.status: creating documentation/man/nhmmer.man
# config.status: creating documentation/man/nhmmscan.man
# config.status: creating documentation/man/phmmer.man
# config.status: creating easel/miniapps/esl-afetch.man
# config.status: creating easel/miniapps/esl-alimanip.man
# config.status: creating easel/miniapps/esl-alimap.man
# config.status: creating easel/miniapps/esl-alimask.man
# config.status: creating easel/miniapps/esl-alimerge.man
# config.status: creating easel/miniapps/esl-alipid.man
# config.status: creating easel/miniapps/esl-alirev.man
# config.status: creating easel/miniapps/esl-alistat.man
# config.status: creating easel/miniapps/esl-compalign.man
# config.status: creating easel/miniapps/esl-compstruct.man
# config.status: creating easel/miniapps/esl-construct.man
# config.status: creating easel/miniapps/esl-histplot.man
# config.status: creating easel/miniapps/esl-mask.man
# config.status: creating easel/miniapps/esl-mixdchlet.man
# config.status: creating easel/miniapps/esl-reformat.man
# config.status: creating easel/miniapps/esl-selectn.man
# config.status: creating easel/miniapps/esl-seqrange.man
# config.status: creating easel/miniapps/esl-seqstat.man
# config.status: creating easel/miniapps/esl-sfetch.man
# config.status: creating easel/miniapps/esl-shuffle.man
# config.status: creating easel/miniapps/esl-ssdraw.man
# config.status: creating easel/miniapps/esl-translate.man
# config.status: creating easel/miniapps/esl-weight.man
# config.status: creating easel/decoy_config.h
# config.status: creating src/p7_config.h
# config.status: creating easel/esl_config.h
# config.status: creating libdivsufsort/divsufsort.h
# config.status: linking src/impl_sse to src/impl
#
#
# HMMER configuration:
#    compiler:             gcc -O3   -pthread
#    host:                 x86_64-pc-linux-gnu
#    linker:
#    libraries:
#    DP implementation:    sse
#
# Now do 'make'  to build HMMER, and optionally:
#        'make check'  to run self tests,
#        'make install'  to install programs and man pages,
#        '(cd easel; make install)'  to install Easel tools.
#
#      SUBDIR easel
#      CC easel.o
#      CC esl_alloc.o
#      CC esl_alphabet.o
#      CC esl_arr2.o
#      CC esl_arr3.o
#      CC esl_bitfield.o
#      CC esl_buffer.o
#      CC esl_cluster.o
#      CC esl_composition.o
#      CC esl_cpu.o
#      CC esl_dirichlet.o
#      CC esl_distance.o
#      CC esl_dmatrix.o
#      CC esl_dsqdata.o
#      CC esl_exponential.o
#      CC esl_fileparser.o
#      CC esl_gamma.o
#      CC esl_gencode.o
#      CC esl_getopts.o
#      CC esl_gev.o
#      CC esl_graph.o
#      CC esl_gumbel.o
#      CC esl_heap.o
#      CC esl_histogram.o
#      CC esl_hmm.o
#      CC esl_huffman.o
#      CC esl_hyperexp.o
#      CC esl_json.o
#      CC esl_keyhash.o
#      CC esl_matrixops.o
#      CC esl_mem.o
#      CC esl_minimizer.o
#      CC esl_mixdchlet.o
#      CC esl_mixgev.o
#      CC esl_mpi.o
#      CC esl_msa.o
#      CC esl_msacluster.o
#      CC esl_msafile.o
#      CC esl_msafile2.o
#      CC esl_msafile_a2m.o
#      CC esl_msafile_afa.o
#      CC esl_msafile_clustal.o
#      CC esl_msafile_phylip.o
#      CC esl_msafile_psiblast.o
#      CC esl_msafile_selex.o
#      CC esl_msafile_stockholm.o
#      CC esl_msashuffle.o
#      CC esl_msaweight.o
#      CC esl_normal.o
#      CC esl_paml.o
#      CC esl_quicksort.o
#      CC esl_random.o
#      CC esl_rand64.o
#      CC esl_randomseq.o
#      CC esl_ratematrix.o
#      CC esl_recorder.o
#      CC esl_red_black.o
#      CC esl_regexp.o
#      CC esl_rootfinder.o
#      CC esl_scorematrix.o
#      CC esl_sq.o
#      CC esl_sqio.o
#      CC esl_sqio_ascii.o
#      CC esl_sqio_ncbi.o
#      CC esl_ssi.o
#      CC esl_stack.o
#      CC esl_stats.o
#      CC esl_stopwatch.o
#      CC esl_stretchexp.o
#      CC esl_subcmd.o
#      CC esl_threads.o
#      CC esl_tree.o
#      CC esl_varint.o
#      CC esl_vectorops.o
#      CC esl_weibull.o
#      CC esl_workqueue.o
#      CC esl_wuss.o
#      CC esl_sse.o
#      CC esl_avx.o
#      CC esl_avx512.o
#      CC esl_neon.o
#      CC esl_vmx.o
#      AR libeasel.a
#      SUBDIR miniapps
#      GEN esl-afetch
#      GEN esl-alimanip
#      GEN esl-alimap
#      GEN esl-alimask
#      GEN esl-alimerge
#      GEN esl-alipid
#      GEN esl-alirev
#      GEN esl-alistat
#      GEN esl-compalign
#      GEN esl-compstruct
#      GEN esl-construct
#      GEN esl-histplot
#      GEN esl-mask
#      GEN esl-mixdchlet
#      GEN esl-reformat
#      GEN esl-selectn
#      GEN esl-seqrange
#      GEN esl-seqstat
#      GEN esl-sfetch
#      GEN esl-shuffle
#      GEN esl-ssdraw
#      GEN esl-translate
#      GEN esl-weight
#      CC cmd_alistat.o
#      CC cmd_downsample.o
#      CC cmd_filter.o
#      CC cmd_index.o
#      GEN easel
#      SUBDIR libdivsufsort
#      CC divsufsort.o
#      AR libdivsufsort.a
#      SUBDIR src
#      CC alimask.o
#      CC build.o
#      CC cachedb.o
#      CC cachedb_shard.o
#      CC emit.o
#      CC errors.o
#      CC evalues.o
#      CC eweight.o
#      CC generic_decoding.o
#      CC generic_fwdback.o
#      CC generic_fwdback_chk.o
#      CC generic_fwdback_banded.o
#      CC generic_null2.o
#      CC generic_msv.o
#      CC generic_optacc.o
#      CC generic_stotrace.o
#      CC generic_viterbi.o
#      CC generic_vtrace.o
#      CC h2_io.o
#      CC heatmap.o
#      CC hmmlogo.o
#      CC hmmdmstr.o
#      CC hmmdmstr_shard.o
#      CC hmmd_search_status.o
#      CC hmmdwrkr.o
#      CC hmmdwrkr_shard.o
#      CC hmmdutils.o
#      CC hmmer.o
#      CC logsum.o
#      CC modelconfig.o
#      CC modelstats.o
#      CC mpisupport.o
#      CC seqmodel.o
#      CC tracealign.o
#      CC p7_alidisplay.o
#      CC p7_bg.o
#      CC p7_builder.o
#      CC p7_domain.o
#      CC p7_domaindef.o
#      CC p7_gbands.o
#      CC p7_gmx.o
#      CC p7_gmxb.o
#      CC p7_gmxchk.o
#      CC p7_hit.o
#      CC p7_hmm.o
#      CC p7_hmmcache.o
#      CC p7_hmmd_search_stats.o
#      CC p7_hmmfile.o
#      CC p7_hmmwindow.o
#      CC p7_pipeline.o
#      CC p7_prior.o
#      CC p7_profile.o
#      CC p7_spensemble.o
#      CC p7_tophits.o
#      CC p7_trace.o
#      CC p7_scoredata.o
#      CC hmmpgmd2msa.o
#      CC fm_alphabet.o
#      CC fm_general.o
#      CC fm_sse.o
#      CC fm_ssv.o
#      AR libhmmer-src.stamp
#      SUBDIR impl_sse
#      CC decoding.o
#      CC fwdback.o
#      CC io.o
#      CC ssvfilter.o
#      CC msvfilter.o
#      CC null2.o
#      CC optacc.o
#      CC stotrace.o
#      CC vitfilter.o
#      CC p7_omx.o
#      CC p7_oprofile.o
#      CC mpi.o
#      AR libhmmer-impl.stamp
#      GEN alimask
#      CC hmmalign.o
#      GEN hmmalign
#      CC hmmbuild.o
#      GEN hmmbuild
#      CC hmmconvert.o
#      GEN hmmconvert
#      CC hmmemit.o
#      GEN hmmemit
#      CC hmmfetch.o
#      GEN hmmfetch
#      GEN hmmlogo
#      CC hmmpgmd.o
#      GEN hmmpgmd
#      CC hmmpgmd_shard.o
#      GEN hmmpgmd_shard
#      CC hmmpress.o
#      GEN hmmpress
#      CC hmmscan.o
#      GEN hmmscan
#      CC hmmsearch.o
#      GEN hmmsearch
#      CC hmmsim.o
#      GEN hmmsim
#      CC hmmstat.o
#      GEN hmmstat
#      CC jackhmmer.o
#      GEN jackhmmer
#      CC phmmer.o
#      GEN phmmer
#      CC nhmmer.o
#      GEN nhmmer
#      CC nhmmscan.o
#      GEN nhmmscan
#      CC makehmmerdb.o
#      GEN makehmmerdb
#      CC hmmc2.o
#      GEN hmmc2
#      CC hmmerfm-exactmatch.o
#      GEN hmmerfm-exactmatch
#      SUBDIR profmark
#      CC create-profmark.o
#      GEN create-profmark
#      CC rocplot.o
#      GEN rocplot
#      SUBDIR easel
#      SUBDIR miniapps
#      SUBDIR libdivsufsort
#      SUBDIR src
#      SUBDIR impl_sse
#      SUBDIR profmark
# /usr/bin/install -c -d /usr/local/bin
# /usr/bin/install -c -d /usr/local/share/man/man1
# make -C src install
# make[1]: Entering directory '/content/hmmer-3.3.2/src'
# for file in alimask hmmalign hmmbuild hmmconvert hmmemit hmmfetch hmmlogo hmmpgmd hmmpgmd_shard hmmpress hmmscan hmmsearch hmmsim hmmstat jackhmmer phmmer nhmmer nhmmscan makehmmerdb; do \
#    /usr/bin/install -c -m 0755 $file /usr/local/bin/ ;\
# done
# make[1]: Leaving directory '/content/hmmer-3.3.2/src'
# make -C documentation install
# make[1]: Entering directory '/content/hmmer-3.3.2/documentation'
# make -C man install
# make[2]: Entering directory '/content/hmmer-3.3.2/documentation/man'
# for file in hmmer hmmalign hmmbuild hmmc2 hmmconvert hmmemit hmmfetch hmmlogo hmmpgmd hmmpgmd_shard hmmpress hmmscan hmmsearch hmmsim hmmstat jackhmmer makehmmerdb phmmer nhmmer nhmmscan alimask; do \
#    /usr/bin/install -c -m 0664 $file.man /usr/local/share/man/man1/${file}.1 ;\
# done
# make[2]: Leaving directory '/content/hmmer-3.3.2/documentation/man'
# make[1]: Leaving directory '/content/hmmer-3.3.2/documentation'
# In file included from hmmbuild.c:13:
# In function ‘usual_master’,
#     inlined from ‘main’ at hmmbuild.c:463:7:
# ../easel/easel.h:164:17: warning: argument 1 range [18446744022169944064, 18446744073709551592] exceeds maximum object size 9223372036854775807 [-Walloc-size-larger-than=]
#   164 |     if ( ((p) = malloc(size)) == NULL)  { \
#       |                 ^~~~~~~~~~~~
# hmmbuild.c:561:3: note: in expansion of macro ‘ESL_ALLOC’
#   561 |   ESL_ALLOC(info, sizeof(*info) * infocnt);
#       |   ^~~~~~~~~
# In file included from hmmbuild.c:6:
# hmmbuild.c: In function ‘main’:
# /usr/include/stdlib.h:540:14: note: in a call to allocation function ‘malloc’ declared here
#   540 | extern void *malloc (size_t __size) __THROW __attribute_malloc__
#       |              ^~~~~~
# In file included from hmmscan.c:14:
# In function ‘serial_master’,
#     inlined from ‘main’ at hmmscan.c:302:16:
# ../easel/easel.h:164:17: warning: argument 1 range [18446743987810205696, 18446744073709551576] exceeds maximum object size 9223372036854775807 [-Walloc-size-larger-than=]
#   164 |     if ( ((p) = malloc(size)) == NULL)  { \
#       |                 ^~~~~~~~~~~~
# hmmscan.c:402:3: note: in expansion of macro ‘ESL_ALLOC’
#   402 |   ESL_ALLOC(info, sizeof(*info) * infocnt);
#       |   ^~~~~~~~~
# In file included from hmmscan.c:11:
# hmmscan.c: In function ‘main’:
# /usr/include/stdlib.h:540:14: note: in a call to allocation function ‘malloc’ declared here
#   540 | extern void *malloc (size_t __size) __THROW __attribute_malloc__
#       |              ^~~~~~

# %% [markdown]
# Скачиваем Pfam
# По ftp доступны разны версии базы. Нас интересует последняя в формате hmm

# %%
#!wget --spider http://ftp.ebi.ac.uk/pub/databases/Pfam/releases/Pfam25.0/Pfam-A.full.gz

# %%
#!wget ftp://ftp.sanger.ac.uk/pub/databases/Pfam/releases/Pfam25.0/Pfam-A.full.gz.

# %%
# !wget http://ftp.ebi.ac.uk/pub/databases/Pfam/releases/Pfam35.0/Pfam-A.hmm.gz
# Out:
# --2025-06-18 00:06:12--  http://ftp.ebi.ac.uk/pub/databases/Pfam/releases/Pfam35.0/Pfam-A.hmm.gz
# Resolving ftp.ebi.ac.uk (ftp.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.ebi.ac.uk (ftp.ebi.ac.uk)|193.62.193.165|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 293000230 (279M) [application/x-gzip]
# Saving to: ‘Pfam-A.hmm.gz’
#
# Pfam-A.hmm.gz       100%[===================>] 279.43M  23.1MB/s    in 14s
#
# 2025-06-18 00:06:27 (20.4 MB/s) - ‘Pfam-A.hmm.gz’ saved [293000230/293000230]

# %% [markdown]
# Извлекаем из архива

# %%
# !gunzip Pfam-A.hmm.gz

# %% [markdown]
# Создаем нужные для hmmer'a файлы

# %%
# !hmmpress Pfam-A.hmm
# Out:
# Working...    done.
# Pressed and indexed 19632 HMMs (19632 names and 19632 accessions).
# Models pressed into binary file:   Pfam-A.hmm.h3m
# SSI index for binary model file:   Pfam-A.hmm.h3i
# Profiles (MSV part) pressed into:  Pfam-A.hmm.h3f
# Profiles (remainder) pressed into: Pfam-A.hmm.h3p

# %%
# !head -n 40 Pfam-A.hmm
# Out:
# HMMER3/f [3.1b2 | February 2015]
# NAME  1-cysPrx_C
# ACC   PF10417.12
# DESC  C-terminal domain of 1-Cys peroxiredoxin
# LENG  40
# ALPH  amino
# RF    no
# MM    no
# CONS  yes
# CS    yes
# MAP   yes
# DATE  Thu Nov  4 19:20:02 2021
# NSEQ  40
# EFFN  17.426758
# CKSUM 4086680297
# GA    21.1 21.1;
# TC    21.1 21.1;
# NC    21 21;
# BM    hmmbuild HMM.ann SEED.ann
# SM    hmmsearch -Z 61295632 -E 1000 --cpu 4 HMM pfamseq
# STATS LOCAL MSV       -7.5463  0.71948
# STATS LOCAL VITERBI   -7.8624  0.71948
# STATS LOCAL FORWARD   -4.3303  0.71948
# HMM          A        C        D        E        F        G        H        I        K        L        M        N        P        Q        R        S        T        V        W        Y
#             m->m     m->i     m->d     i->m     i->i     d->m     d->d
#   COMPO   2.28046  4.31208  2.83393  2.63913  3.90855  2.69988  3.89812  3.33401  2.56310  2.85023  3.99954  3.22924  2.52123  2.90328  3.31238  2.94055  2.70512  2.59551  3.49266  3.82715
#           2.68618  4.42225  2.77519  2.73123  3.46354  2.40513  3.72494  3.29354  2.67741  2.69355  4.24690  2.90347  2.73739  3.18146  2.89801  2.37887  2.77519  2.98518  4.58477  3.61503
#           0.00226  6.48754  7.20989  0.61958  0.77255  0.00000        *
#       1   0.29666  6.14436  6.78514  6.79783  7.06332  2.55785  7.22049  6.57837  6.66651  6.27638  3.28757  5.91223  5.83978  6.69238  6.58162  2.20136  4.83343  5.59959  8.41086  7.43107      1 A - - H
# 11     2-thiour_desulf      PF04463.15        338     2.11    137   0.59   0.57   0.46   0.02
# 12     23ISL                PF16620.8          16     1.48    162   0.59   0.61   0.54   0.07

# %% [markdown]
# The columns are:
#
# **idx**
# The index of this profile, numbering each on in the file starting from 1.
#
# **name**
# The name of the profile.
#
# **accession**
# The optional accession of the profile, or "-" if there is none.
#
# **nseq**
# The number of sequences that the profile was estimated from.
#
# **eff_nseq**
# The effective number of sequences that the profile was estimated from, after HMMER applied an effective sequence number calculation such as the default entropy weighting.
#
# **M**
# The length of the model in consensus residues (match states).
#
# **relent**
# Mean relative entropy per match state, in bits. This is the expected (mean) score per consensus position. This is what the default entropy-weighting method for effective sequence number estimation focuses on, so for default HMMER3 models, you expect this value to reflect the default target for entropy-weighting.
#
# **info**
# Mean information content per match state, in bits. Probably not useful. Information content is a slightly different calculation than relative entropy.
#
# **p relE**
# Mean positional relative entropy, in bits. This is a fancier version of the per-match-state relative entropy, taking into account the transition (insertion/deletion) probabilities; it may be a more accurate estimation of the average score contributed per model consensus position.
#
# **compKL**
# Kullback-Leibler distance between the model's overall average residue composition and the default background frequency distribution. The higher this number, the more biased the residue composition of the profile is. Highly biased profiles can slow the HMMER3 acceleration pipeline, by causing too many nonhomologous sequences to pass the filters.

# %% [markdown]
# Индексируем файл

# %%
# !hmmfetch --index Pfam-A.hmm.h3m
# Out:
# Working...    done.
# Indexed 19632 HMMs (19632 names and 19632 accessions).
# SSI index written to file Pfam-A.hmm.h3m.ssi

# %% [markdown]
# Скачиваем протеом

# %%
# !wget https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/190/715/GCF_000190715.1_v1.0/GCF_000190715.1_v1.0_protein.faa.gz
# Out:
# --2025-06-18 00:07:25--  https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/190/715/GCF_000190715.1_v1.0/GCF_000190715.1_v1.0_protein.faa.gz
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.7, 130.14.250.10, 130.14.250.11, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.7|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3600361 (3.4M) [application/x-gzip]
# Saving to: ‘GCF_000190715.1_v1.0_protein.faa.gz’
#
# GCF_000190715.1_v1. 100%[===================>]   3.43M  1.80MB/s    in 1.9s
#
# 2025-06-18 00:07:29 (1.80 MB/s) - ‘GCF_000190715.1_v1.0_protein.faa.gz’ saved [3600361/3600361]

# %%
# !mv ./GCF_000190715.1_v1.0_protein.faa.gz ./proteome.faa.gz
# !gunzip -rd proteome.faa.gz proteome.faa

# %%
# !mkdir hmm

# %% [markdown]
# ## Поиск генов

# %% [markdown]
# Скачиваем таблицу с генами

# %%
# !wget "https://docs.google.com/spreadsheets/d/1d3114LoBXHQACG9iqVDZtQ5pmf-rUYtbHhpEBF6q_Qc/export?format=csv&gid=1397071643" -O "hmm/genes_info.csv"
# Out:
# --2025-06-18 00:07:30--  https://docs.google.com/spreadsheets/d/1d3114LoBXHQACG9iqVDZtQ5pmf-rUYtbHhpEBF6q_Qc/export?format=csv&gid=1397071643
# Resolving docs.google.com (docs.google.com)... 172.253.118.102, 172.253.118.101, 172.253.118.113, ...
# Connecting to docs.google.com (docs.google.com)|172.253.118.102|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://doc-0o-b0-sheets.googleusercontent.com/export/54bogvaave6cua4cdnls17ksc4/8p3nncv85p0ho1q64c22cd70dc/1750205250000/109540323021403462314/*/1d3114LoBXHQACG9iqVDZtQ5pmf-rUYtbHhpEBF6q_Qc?format=csv&gid=1397071643 [following]
# Warning: wildcards not supported in HTTP.
# --2025-06-18 00:07:31--  https://doc-0o-b0-sheets.googleusercontent.com/export/54bogvaave6cua4cdnls17ksc4/8p3nncv85p0ho1q64c22cd70dc/1750205250000/109540323021403462314/*/1d3114LoBXHQACG9iqVDZtQ5pmf-rUYtbHhpEBF6q_Qc?format=csv&gid=1397071643
# Resolving doc-0o-b0-sheets.googleusercontent.com (doc-0o-b0-sheets.googleusercontent.com)... 74.125.68.132, 2404:6800:4003:c02::84
# Connecting to doc-0o-b0-sheets.googleusercontent.com (doc-0o-b0-sheets.googleusercontent.com)|74.125.68.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/csv]
# Saving to: ‘hmm/genes_info.csv’
#
# hmm/genes_info.csv      [  <=>               ] 167.55K   772KB/s    in 0.2s
#
# 2025-06-18 00:07:33 (772 KB/s) - ‘hmm/genes_info.csv’ saved [171573]

# %%
# !head hmm/genes_info.csv
# Out:
# HGNC approved symbol,Product,Function,Protein complex,Target entity,HGNC approved name,UniProt ID (human),Pfam domains,UniProt ID (mouse),Modification
# A1CF,U,RNA modification,APOB_mRNA_editosome,"mRNA, mC",APOBEC1 complementation factor,A1CF_HUMAN,"DND1_DSRM PF14709 445-523, RRM_1 PF00076 58-127 138-203, RRM_6 PF14259 233-297",A1CF_MOUSE,RNA deamination
# ACINU,#,RNA modification,#,mRNA,Apoptotic chromatin condensation inducer in the nucleus (Acinus),ACINU_HUMAN,PF16294;PF02037,ACINU_MOUSE,Alternative splicing
# ACTB,#,Chromatin remodeling cofactor,"BAF, nBAF, npBAF, PBAF, SWI/SNF-like EPAFB, bBAF, SWI/SNF BRM-BRG1, NuA4, NuA4-related complex",#,"actin, beta",ACTB_HUMAN,Actin PF00022 2-375,ACTB_MOUSE,#
# ACTL6A,#,Chromatin remodeling cofactor,"BAF, npBAF, PBAF, SWI/SNF_Brg1(I), SWI/SNF_Brg1(II), SWI/SNF_Brm, SWI/SNF-like_EPAFa, WINAC, SWI/SNF-like EPAFB, SWI/SNF BRM-BRG1, Ino80, NuA4, NuA4-related complex, SRCAP",#,actin-like 6A,ACL6A_HUMAN,Actin PF00022 8-429,ACL6A_MOUSE,#
# ACTL6B,#,Chromatin remodeling cofactor,"BAF, nBAF, PBAF, SWI/SNF_Brg1(I), SWI/SNF_Brg1(II), SWI/SNF_Brm, SWI/SNF BRM-BRG1",#,actin-like 6B,ACL6B_HUMAN,Actin PF00022 8-426,ACL6B_MOUSE,#
# ACTR3B,#,Chromatin remodeling,#,"H2A, H3, H4",ARP3 actin-related protein 3 homolog B (yeast),ARP3B_HUMAN,Actin PF00022 3-412,ARP3B_MOUSE,#
# ACTR5,#,Chromatin remodeling,Ino80,#,ARP5 actin-related protein 5 homolog (yeast),ARP5_HUMAN,Actin PF00022 30-570,ARP5_MOUSE,#
# ACTR6,#,Chromatin remodeling cofactor,SRCAP,#,ARP6 actin-related protein 6 homolog (yeast),ARP6_HUMAN,Actin PF00022 1-395,ARP6_MOUSE,#
# ACTR8,#,Histone modification read,Ino80,#,ARP8 actin-related protein 8 homolog (yeast),ARP8_HUMAN,Actin PF00022 43-621,ARP8_MOUSE,#

# %% [markdown]
# Возьмём все возможные семейства

# %%
import pandas as pd

# %%
genes_info = "hmm/genes_info.csv"
data = pd.read_csv(genes_info)
data.head()
# Out:
#   HGNC approved symbol Product                       Function  \
# 0                 A1CF       U               RNA modification
# 1                ACINU       #               RNA modification
# 2                 ACTB       #  Chromatin remodeling cofactor
# 3               ACTL6A       #  Chromatin remodeling cofactor
# 4               ACTL6B       #  Chromatin remodeling cofactor
#
#                                      Protein complex Target entity  \
# 0                                APOB_mRNA_editosome      mRNA, mC
# 1                                                  #          mRNA
# 2  BAF, nBAF, npBAF, PBAF, SWI/SNF-like EPAFB, bB...             #
# 3  BAF, npBAF, PBAF, SWI/SNF_Brg1(I), SWI/SNF_Brg...             #
# 4  BAF, nBAF, PBAF, SWI/SNF_Brg1(I), SWI/SNF_Brg1...             #
#
#                                   HGNC approved name UniProt ID (human)  \
# 0                     APOBEC1 complementation factor         A1CF_HUMAN
# 1  Apoptotic chromatin condensation inducer in th...        ACINU_HUMAN
# 2                                        actin, beta         ACTB_HUMAN
# 3                                      actin-like 6A        ACL6A_HUMAN
# 4                                      actin-like 6B        ACL6B_HUMAN
#
#                                         Pfam domains UniProt ID (mouse)  \
# 0  DND1_DSRM PF14709 445-523, RRM_1 PF00076 58-12...         A1CF_MOUSE
# 1                                    PF16294;PF02037        ACINU_MOUSE
# 2                                Actin PF00022 2-375         ACTB_MOUSE
# 3                                Actin PF00022 8-429        ACL6A_MOUSE
# 4                                Actin PF00022 8-426        ACL6B_MOUSE
#
#            Modification
# 0       RNA deamination
# 1  Alternative splicing
# 2                     #
# 3                     #
# 4                     #

# %%
domains = set([s.split()[0] for s in data['Pfam domains'].to_list()])
list(domains)[:10]
# Out:
# ['AAA',
#  'PrmA',
#  '#',
#  'LEDGF',
#  'Pfam-B_10398',
#  'Las1',
#  '2OG-FeII_Oxy_2',
#  'YL1_C',
#  'PF09745',
#  'PHD_2']

# %%
import os

for domain in domains:
    # !hmmfetch Pfam-A.hmm.h3m "{domain}" > "hmm/{domain}.hmm"
    with open(f'hmm/{domain}.hmm') as f:
        if f.readlines() == []:
            os.remove(f'hmm/{domain}.hmm')
# Out:
# Error: HMM # not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_10398 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF09745 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF00270;PF00035;PF04408;PF00271;PF07717 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM DUF3588 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM TFIID_90kDa not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_10178 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_30131 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_18067 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_11232 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_188 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_13426 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_1400 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF01189 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_19319 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_18810 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF01398; not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_20901 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF12934, not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF04096;PF12110 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_14282 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM DUF1726 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_27974 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_6035 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_15485 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_16181 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_17110 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF04146 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM DUF3635 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_11880 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_20206 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_9491 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_30754 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_16193 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM DUF3590 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_2325 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF12414;PF00076 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF08081;PF00076 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF01585;PF17780;PF00076;PF00641 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_32546 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM DUF1546 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_20467 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM DLD not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_28044 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_9879 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_2986 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_2662 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_42536 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_12208 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF05891 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF01585;PF00076 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_11259 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM DUF2348 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF13532 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_29325 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF11708 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_7713 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_2058 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_8588 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_24421 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_5669 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_22101 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_15854 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF16294;PF02037 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_4074 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_1720 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_25613 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_4954 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_17191 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_24604 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF00076;PF00098 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF01509 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_39033 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_34716 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_12581 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_5206 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF00013;PF16274;PF16568 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_13909 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_1700 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Homeobox not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF00076 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_3219 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM CDC73 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF02037;PF00622 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_8506 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_3428 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF17098 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF00270;PF00271 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF00076;PF07744 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_21220 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_13436 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF00270;PF00271;PF08061 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF00249; not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_16851 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_17557 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_22064 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_25595 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_22190 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_18257 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_12198 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_7774 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_11420 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_10841 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_20489 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_10362 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF02792 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pkinase_Tyr not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_793 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_18005 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_2740 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF00076;PF11835 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_13260 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF15440 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_5729 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_25018 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF11532;PF00076 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_13759 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_11743 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF05971 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF10294 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Cupin_4 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF08241 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF15912 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_28511 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_41790 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_12165 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM DUF1767 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_77655 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM NOSIC not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_139748 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_2570 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF08351;PF13718;PF05127;PF13725 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_25912 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_38998 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF00012 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF00849 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_24677 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_24699 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_26289 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_2743 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_16491 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF15230 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_13705 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF03226 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Fork_head not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF18408 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF01480;PF00076 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_21314 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_7181 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_37192 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_26038 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF09750;PF01805 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF00651;PF00096 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_18604 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_10240 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF05063 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM DUF4414 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_17306 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM PF00642 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_21577 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_23340 not found in SSI index for file Pfam-A.hmm.h3m
#
#
# Error: HMM Pfam-B_1253 not found in SSI index for file Pfam-A.hmm.h3m

# %%
from os import walk
import requests

table = []
files = next(walk("hmm"), (None, None, []))[2]
for file in files:
    output = !hmmsearch --notextw --noali "hmm/{file}" proteome.faa
    if len(output) > 18 and len(output[18].split()) > 8:
        link = f'https://www.ncbi.nlm.nih.gov/gene/?term={output[18].split()[8]}'
        f = requests.get(link)
        t = str(f.content)
        start = t.find("<title>") + 7
        end = t[start:].find("</title>")
        table.append([file[:-4], t[start:start + end].split()[0]])

# %%
df = pd.DataFrame(table, columns=["Проверяемое семейство", "Название гена"])
df = df.set_index("Проверяемое семейство")
df.head()
# Out:
#                            Название гена
# Проверяемое семейство
# Las1                   DICPUDRAFT_151438
# DEAD                    DICPUDRAFT_50558
# Ank_2                   DICPUDRAFT_97659
# Leo1                   DICPUDRAFT_157421
# LRR_1                   DICPUDRAFT_50592

# %% [markdown]
# В этом файлике будет лежать информация о семействе и соответствующем ему гене организма. Файл прилагается в репозитории

# %%
df.to_csv("hmmer.csv")

# %% [markdown]
# Пример

# %%
families = [
    'TUDOR',
    'Chromo',

'Pkinase',
'Acetyltransf_1',
'DnaJ',
'Cullin',
'CPSF_A',
'zf-rbx1',
'WD40',
'Cir_N',
'HIRA_B'
]

# %%
df.loc[families, :]
# Out:
#                            Название гена
# Проверяемое семейство
# TUDOR                   DICPUDRAFT_49610
# Chromo                 DICPUDRAFT_154353
# Pkinase                DICPUDRAFT_147525
# Acetyltransf_1          DICPUDRAFT_77757
# DnaJ                    DICPUDRAFT_83269
# Cullin                 DICPUDRAFT_151475
# CPSF_A                  DICPUDRAFT_52125
# zf-rbx1                 DICPUDRAFT_88388
# WD40                   DICPUDRAFT_151152
# Cir_N                   DICPUDRAFT_99731
# HIRA_B                  DICPUDRAFT_87573
